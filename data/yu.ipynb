# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("FineTuneTest.csv").iloc[1:,1]
data=np.zeros(len(df)//2)
for i in range(len(data)):
    data[i]=df.iloc[i*2]

# %%
pd.DataFrame(data).to_csv("FineTuneTest.csv")

# %%
data=data[:2500]
plt.plot(range(len(data)),np.array(data))
