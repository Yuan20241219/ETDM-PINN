# %%
# 结构信息

# %%
"""
SCL线性计算模块
计算正确
"""

# %%
import torch
import pandas as pd
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn as nn
import numpy as np

# %%
dof=5  #结构自由度
dt=0.02 #时间步长度
beta=0.25 
gama=0.5
m=30   #时间步数
alpha=0.2 #刚度折减系数

# %%
#质量矩阵
m=torch.tensor([5000.0,5000.0,5000.0,5000.0,5000.0])  #kg
M=torch.diag(m)

# %%
#刚度矩阵
k=torch.tensor([1e7,1e7,1e7,1e7,1e7])  #层间刚度 N/m
K0=torch.tensor([
    [k[0]+k[1],-k[1],0,0,0],
    [-k[1],k[1]+k[2],-k[2],0,0],
    [0,-k[2],k[2]+k[3],-k[3],0],
    [0,0,-k[2],k[3]+k[4],-k[4]],
    [0,0,0,-k[4],k[4]]
])

# %%
K_re=torch.tensor([[-k[0],k[1],0,0,0],
    [0,-k[1],k[2],0,0],
    [0,0,-k[2],k[3],0],
    [0,0,0,-k[3],k[4]],
    [0,0,0,0,-k[4]]])

# %%
zeta = 0.02; w1 = 0.4479; w2 = 1.16   #定义结构阻尼比，1、2阶频率 9层
a_coe = 2*w1*w2*zeta/(w1+w2); b_coe = 2*zeta/(w1+w2)
C =a_coe*M + b_coe*K0  #计算瑞利阻尼

# %%
# Newmark_beta法计算系数
a0=1/(beta*dt**2)
a1=1/(beta*dt)
a2=1/(2*beta)-1
a3=gama/(beta*dt)
a4=gama/beta-1
a5=(gama/beta-2)*dt/2

# %%
L=torch.zeros((dof,dof+1))
L[:,0]=m
L[:,1:]=-torch.eye(dof)

# %%
H=torch.zeros((dof*2,dof*2))
H[dof:,:dof]=-torch.inverse(M)@K0
H[:dof,dof:]=torch.eye(dof)
H[dof:,dof:]=-torch.inverse(M)@C

# %%
W=torch.zeros((dof*2,dof+1))
W[dof:]=torch.inverse(M)@L

# %%
S1=torch.zeros((dof*2,dof*2))
S1[:dof,:dof]=a3*torch.eye(dof)
S1[dof:,:dof]=a0*torch.eye(dof)

# %%
S2=torch.zeros((dof*2,dof*2))
S2[:dof,:dof]=a4*torch.eye(dof)
S2[dof:,:dof]=a1*torch.eye(dof)
S2[:dof,dof:]=a5*torch.eye(dof)
S2[dof:,dof:]=a2*torch.eye(dof)

# %%
Q1=-torch.inverse((H-S1))@S2@W

# %%
Q2=-torch.inverse((H-S1))@W

# %%
T=-torch.inverse(H-S1)@(S1+S2@H)

# %%
A1_1=Q2
A2_1=T@Q2+Q1
A=torch.stack((A1_1,A2_1))
for i in range(2,600):
    A=torch.cat((A,torch.unsqueeze(T@A[-1],0)),dim=0)
A=torch.flip(A,[0])

# %%
A.shape
# Out:
# torch.Size([600, 10, 6])

# %%
# 得到P
acc=pd.read_csv("../data/地震加速度.csv")  # m/s^2
acc=torch.tensor(acc.iloc[1:,1:].values)

# %%
plt.figure(figsize=(15,5))
plt.plot(np.arange(0,30,0.02),acc[0,:].detach())
plt.ylabel("a/(m/s^2)")
plt.xlabel("t/s")
plt.show()

# %%
import torch
import torch.nn as nn

class LSTMModule(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(LSTMModule, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc1 = nn.Linear(hidden_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, output_size)
        self.relu = nn.ReLU()

    def forward(self, x):
        h0 = torch.zeros(self.lstm.num_layers, x.size(0), self.lstm.hidden_size).to(x.device)
        c0 = torch.zeros(self.lstm.num_layers, x.size(0), self.lstm.hidden_size).to(x.device)
        out, _ = self.lstm(x, (h0, c0))
        # out = self.fc1(out[:, -1, :])
        out = self.fc1(self.relu(out))
        out = self.relu(out)
        out = self.fc2(out)
        return out

# %%
# 单层神经网络，无激活函数
class SCL(nn.Module):
    def __init__(self,in_channels,out_channels,kernel_size,kernel_A):
        super(SCL,self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels,kernel_size,stride=1,bias=False)
        self.conv.weight.data = kernel_A
        self.conv.weight.requires_grad = False
        
    def forward(self, x):
        x = self.conv(x)
        return x

# %%
#定义损失函数
def V2Fnl(V):
    V_re=torch.zeros_like(V[:5,:])
    V_re[0,:]=V[0,:]
    V_re[1:,:]=V[1:5,:]-V[:4,:]
    Fnl=1000*K_re@(V_re**3)
    return Fnl

# %%
# 得到P
acc=pd.read_csv("../data/地震加速度.csv")  # m/s^2
acc=acc.iloc[1,1:].values
ag=acc
dt=0.02

# %%
fnl=pd.read_csv("非线性恢复力1.csv").iloc[:,1:]

# %%
a=torch.tensor(ag).unsqueeze(0)
f=torch.tensor(np.array(fnl))
F=torch.cat((a,f),dim=0)
pad=torch.zeros((6,599))
F_pad=torch.cat((pad,F),dim=1)

# %%
P=F.float()
V=torch.zeros((10,P.shape[1]))

# %%
for i in range(600):
    P_t=P[:,:i+1]
    A_1=A[-P_t.shape[1]:].float()
    for j in range(P_t.shape[1]):
        V[:,i]+=A_1[j]@P_t[:,j]

# %%
plt.figure(figsize=(15,5))
plt.plot(range(1500),V[0,:].detach())

# %%
V.shape
# Out:
# torch.Size([10, 1500])

# %%
for i in range(600,P.shape[1]):
    P_t=P[:,i-599:i+1]
    A_1=A.float()
    for j in range(P_t.shape[1]):
        V[:,i]+=A_1[j]@P_t[:,j]

# %%
plt.figure(figsize=(15,5))
plt.plot(range(1500),V[0,:].detach())

# %%
Fnl_re=V2Fnl(V)

# %%
plt.figure(figsize=(15,5))
plt.plot(range(1500),Fnl_re[0,:].detach())

# %%
A.shape
# Out:
# torch.Size([600, 10, 6])

# %%
A_kernel=A.permute((1,2,0)).unsqueeze(1)
scl_model=SCL(1,10,(6,600),A_kernel)

# %%
F_pad.unsqueeze(0).unsqueeze(0).float().shape
# Out:
# torch.Size([1, 1, 6, 2099])

# %%
V_from_model=scl_model(F_pad.unsqueeze(0).unsqueeze(0).float())

# %%
plt.figure(figsize=(15,5))
plt.plot(range(1500),V_from_model[0,0,0,:].detach())

# %%
V_from_model.shape
# Out:
# torch.Size([1, 10, 1, 1500])

# %%
Fnl_from_model=V2Fnl(V_from_model[0,:,0,:])
